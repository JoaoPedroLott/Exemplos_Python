# %%
# !pip install phonenumbers
# Out:
# Collecting phonenumbers
#   Downloading phonenumbers-8.12.28-py2.py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 29.4 MB/s
# Installing collected packages: phonenumbers
# Successfully installed phonenumbers-8.12.28

# %%
import phonenumbers
from phonenumbers import geocoder

# %%
phone = input('Informe o telefone (formato -> +55xxxxxxxxxxx): ')
# Out:
# Informe o telefone (formato -> +55xxxxxxxxxxx): +5531993373954

# %%
phone_numbers = phonenumbers.parse(phone)

# %%
print(geocoder.description_for_number(phone_numbers, 'pt'))
# Out:
# Minas Gerais
