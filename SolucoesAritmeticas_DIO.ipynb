# %% [markdown]
# # Desafios DIO - Bootcamp Banco Carrefour Data engineer

# %%
nota = int(input())

if 0 <= nota < 1:
    print('E')
elif 1 <= nota <= 35:
    print('D')
elif 36 <= nota <= 60:
    print('C')
elif 61 <= nota <= 85:
    print('B')
elif 86 <= nota <= 100:
    print('A')
# Out:
# 5
# D

# %%
x = int(input())

for i in range (0,10):
  #complete
  print(f'N[{i}] = {x}')
  x = x*2
# Out:
# 51
# X[0] = 51
# X[1] = 102
# X[2] = 204
# X[3] = 408
# X[4] = 816
# X[5] = 1632
# X[6] = 3264
# X[7] = 6528
# X[8] = 13056
# X[9] = 26112

# %%
#a = [float(x) for x in input().split()]
a = [5.0,2.0,4.0]

#complete o desafio
if a[0] + a[1] > a[2] and a[0] + a[2] > a[1] and a[1] + a[2] > a[0]:  
    print(f"Perimetro = {sum(a):.1f}")
else:
    print(f"Area = {((a[0] + a[1]) *a[2]) / 2:.1f}")
# Out:
# Perimetro = 11.0
